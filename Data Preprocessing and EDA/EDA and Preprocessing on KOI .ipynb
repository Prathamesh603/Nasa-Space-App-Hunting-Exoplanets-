# %%
import pandas as pd 
df = pd.read_csv('../Data/Raw data/KOI(Cumulative List).csv')

# %%
df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_vet_stat  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED         Done
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED         Done
# 2      3  10811496  K00753.01           NaN       CANDIDATE         Done
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE         Done
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED         Done
#
#   koi_vet_date koi_pdisposition  koi_score  koi_fpflag_nt  ...  \
# 0   2018-08-16        CANDIDATE      1.000              0  ...
# 1   2018-08-16        CANDIDATE      0.969              0  ...
# 2   2018-08-16        CANDIDATE      0.000              0  ...
# 3   2018-08-16   FALSE POSITIVE      0.000              0  ...
# 4   2018-08-16        CANDIDATE      1.000              0  ...
#
#    koi_dicco_mdec  koi_dicco_mdec_err  koi_dicco_msky koi_dicco_msky_err  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Columns: 141 entries, rowid to koi_dikco_msky_err
# dtypes: float64(117), int64(7), object(17)
# memory usage: 10.3+ MB

# %%
df.shape
# Out:
# (9564, 141)

# %%
print(df.columns)
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_vet_stat', 'koi_vet_date', 'koi_pdisposition', 'koi_score',
#        'koi_fpflag_nt',
#        ...
#        'koi_dicco_mdec', 'koi_dicco_mdec_err', 'koi_dicco_msky',
#        'koi_dicco_msky_err', 'koi_dikco_mra', 'koi_dikco_mra_err',
#        'koi_dikco_mdec', 'koi_dikco_mdec_err', 'koi_dikco_msky',
#        'koi_dikco_msky_err'],
#       dtype='object', length=141)

# %%
df
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition koi_vet_stat  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED         Done
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED         Done
# 2         3  10811496  K00753.01           NaN       CANDIDATE         Done
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE         Done
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED         Done
# ...     ...       ...        ...           ...             ...          ...
# 9559   9560  10090151  K07985.01           NaN  FALSE POSITIVE         Done
# 9560   9561  10128825  K07986.01           NaN       CANDIDATE         Done
# 9561   9562  10147276  K07987.01           NaN  FALSE POSITIVE         Done
# 9562   9563  10155286  K07988.01           NaN       CANDIDATE         Done
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE         Done
#
# ...

# %%
columns_to_keep = ['kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
       'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
       'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
       'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
       'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
       'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
       'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
       'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
       'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
       'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
       'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
       'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag']
    


# Keep only relevant columns
df_clean = df[columns_to_keep] 

# Optional: Drop rows with missing values
# df_clean = df_clean.dropna()

# %%
df_clean.head().shape
# Out:
# (5, 49)

# %%
df_clean
# Out:
# Empty DataFrame
# Columns: [kepid, kepoi_name, kepler_name, koi_disposition, koi_pdisposition, koi_score, koi_fpflag_nt, koi_fpflag_ss, koi_fpflag_co, koi_fpflag_ec, koi_period, koi_period_err1, koi_period_err2, koi_time0bk, koi_time0bk_err1, koi_time0bk_err2, koi_impact, koi_impact_err1, koi_impact_err2, koi_duration, koi_duration_err1, koi_duration_err2, koi_depth, koi_depth_err1, koi_depth_err2, koi_prad, koi_prad_err1, koi_prad_err2, koi_teq, koi_teq_err1, koi_teq_err2, koi_insol, koi_insol_err1, koi_insol_err2, koi_model_snr, koi_tce_plnt_num, koi_tce_delivname, koi_steff, koi_steff_err1, koi_steff_err2, koi_slogg, koi_slogg_err1, koi_slogg_err2, koi_srad, koi_srad_err1, koi_srad_err2, ra, dec, koi_kepmag]
# Index: []
#
# [0 rows x 49 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              0 non-null      int64
#  1   kepoi_name         0 non-null      object
#  2   kepler_name        0 non-null      object
#  3   koi_disposition    0 non-null      object
#  4   koi_pdisposition   0 non-null      object
#  5   koi_score          0 non-null      float64
#  6   koi_fpflag_nt      0 non-null      int64
#  7   koi_fpflag_ss      0 non-null      int64
#  8   koi_fpflag_co      0 non-null      int64
#  9   koi_fpflag_ec      0 non-null      int64
#  10  koi_period         0 non-null      float64
#  11  koi_period_err1    0 non-null      float64
#  12  koi_period_err2    0 non-null      float64
#  13  koi_time0bk        0 non-null      float64
#  14  koi_time0bk_err1   0 non-null      float64
#  15  koi_time0bk_err2   0 non-null      float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count of each disposition
sns.countplot(x='koi_disposition', data=df_clean)
plt.title('Distribution of KOI Dispositions')
plt.xlabel('Disposition')  
plt.ylabel('Count')
plt.show()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              0 non-null      int64
#  1   kepoi_name         0 non-null      object
#  2   kepler_name        0 non-null      object
#  3   koi_disposition    0 non-null      object
#  4   koi_pdisposition   0 non-null      object
#  5   koi_score          0 non-null      float64
#  6   koi_fpflag_nt      0 non-null      int64
#  7   koi_fpflag_ss      0 non-null      int64
#  8   koi_fpflag_co      0 non-null      int64
#  9   koi_fpflag_ec      0 non-null      int64
#  10  koi_period         0 non-null      float64
#  11  koi_period_err1    0 non-null      float64
#  12  koi_period_err2    0 non-null      float64
#  13  koi_time0bk        0 non-null      float64
#  14  koi_time0bk_err1   0 non-null      float64
#  15  koi_time0bk_err2   0 non-null      float64
# ...

# %%
# Select numeric columns only
numeric_cols = [
    'koi_period', 'koi_duration', 'koi_depth', 'koi_prad',
    'koi_ror', 'koi_srho', 'koi_sma', 'koi_incl',
    'koi_teq', 'koi_insol', 'koi_impact'
]

sns.pairplot(df_clean, vars=numeric_cols, hue='koi_disposition', corner=True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr = df_clean[numeric_cols].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df_clean['encoded_labels'] = encoder.fit_transform(df_clean['koi_disposition'])

# %%
df_clean.head()
# Out:
#       kepid kepoi_name koi_disposition  koi_period  koi_duration  koi_depth  \
# 0  10797460  K00752.01       CONFIRMED    9.488036       2.95750      615.8
# 1  10797460  K00752.02       CONFIRMED   54.418383       4.50700      874.8
# 2  10811496  K00753.01       CANDIDATE   19.899140       1.78220    10829.0
# 3  10848459  K00754.01  FALSE POSITIVE    1.736952       2.40641     8079.2
# 4  10854555  K00755.01       CONFIRMED    2.525592       1.65450      603.3
#
#    koi_prad   koi_ror  koi_srho  koi_sma  koi_incl  koi_teq  koi_insol  \
# 0      2.26  0.022344   3.20796   0.0853     89.66    793.0      93.59
# 1      2.83  0.027954   3.02368   0.2734     89.57    443.0       9.11
# 2     14.60  0.154046   7.29555   0.1419     88.96    638.0      39.30
# 3     33.46  0.387394   0.22080   0.0267     67.09   1395.0     891.96
# 4      2.75  0.024064   1.98635   0.0374     85.41   1406.0     926.16
#
#    koi_impact  encoded_labels
# 0       0.146               1
# ...

# %%
df_clean['kepid'].nunique()
# Out:
# 7926

# %%
df_clean.shape
# Out:
# (9200, 15)

# %% [markdown]
# ### So as we see the no of unique id are 7926 and the total rows are 9200 so we can not use the kepid in training it affect the model accuracy and it's just an id it not carry any valuable info

# %%
df_clean.drop('kepid',axis=1,inplace=True)

# %%
df_clean.drop('koi_disposition',axis=1,inplace=True)

# %%
df_clean.head()
# Out:
#   kepoi_name  koi_period  koi_duration  koi_depth  koi_prad   koi_ror  \
# 0  K00752.01    9.488036       2.95750      615.8      2.26  0.022344
# 1  K00752.02   54.418383       4.50700      874.8      2.83  0.027954
# 2  K00753.01   19.899140       1.78220    10829.0     14.60  0.154046
# 3  K00754.01    1.736952       2.40641     8079.2     33.46  0.387394
# 4  K00755.01    2.525592       1.65450      603.3      2.75  0.024064
#
#    koi_srho  koi_sma  koi_incl  koi_teq  koi_insol  koi_impact  encoded_labels
# 0   3.20796   0.0853     89.66    793.0      93.59       0.146               1
# 1   3.02368   0.2734     89.57    443.0       9.11       0.586               1
# 2   7.29555   0.1419     88.96    638.0      39.30       0.969               0
# 3   0.22080   0.0267     67.09   1395.0     891.96       1.276               2
# 4   1.98635   0.0374     85.41   1406.0     926.16       0.701               1

# %%
df_clean['kepoi_name']
# Out:
# 0       K00752.01
# 1       K00752.02
# 2       K00753.01
# 3       K00754.01
# 4       K00755.01
#           ...
# 9559    K07985.01
# 9560    K07986.01
# 9561    K07987.01
# 9562    K07988.01
# 9563    K07989.01
# Name: kepoi_name, Length: 9200, dtype: object

# %%
df_clean.drop('kepoi_name',axis=1,inplace=True)

# %%
df_clean.head()
# Out:
#    koi_period  koi_duration  koi_depth  koi_prad   koi_ror  koi_srho  koi_sma  \
# 0    9.488036       2.95750      615.8      2.26  0.022344   3.20796   0.0853
# 1   54.418383       4.50700      874.8      2.83  0.027954   3.02368   0.2734
# 2   19.899140       1.78220    10829.0     14.60  0.154046   7.29555   0.1419
# 3    1.736952       2.40641     8079.2     33.46  0.387394   0.22080   0.0267
# 4    2.525592       1.65450      603.3      2.75  0.024064   1.98635   0.0374
#
#    koi_incl  koi_teq  koi_insol  koi_impact  encoded_labels
# 0     89.66    793.0      93.59       0.146               1
# 1     89.57    443.0       9.11       0.586               1
# 2     88.96    638.0      39.30       0.969               0
# 3     67.09   1395.0     891.96       1.276               2
# 4     85.41   1406.0     926.16       0.701               1

# %%
import os

# %%
os.makedirs('../Data/Clean Data',exist_ok=True)

# %%
df_clean.to_csv('../Data/Clean Data/kepler_koi_clean.csv',index=False)

# %%
df_clean
# Out:
#       koi_period  koi_duration  koi_depth  koi_prad   koi_ror  koi_srho  \
# 0       9.488036       2.95750      615.8      2.26  0.022344   3.20796
# 1      54.418383       4.50700      874.8      2.83  0.027954   3.02368
# 2      19.899140       1.78220    10829.0     14.60  0.154046   7.29555
# 3       1.736952       2.40641     8079.2     33.46  0.387394   0.22080
# 4       2.525592       1.65450      603.3      2.75  0.024064   1.98635
# ...          ...           ...        ...       ...       ...       ...
# 9559    0.527699       3.22210     1579.2     29.35  0.297633   0.16318
# 9560    1.739849       3.11400       48.5      0.72  0.006379   0.50770
# 9561    0.681402       0.86500      103.6      1.07  0.009444   8.97692
# 9562  333.486169       3.19900      639.1     19.30  0.022590  85.88623
# 9563    4.856035       3.07800       76.7      1.05  0.008076   1.40645
#
#       koi_sma  koi_incl  koi_teq  koi_insol  koi_impact  encoded_labels
# ...

# %%
df['koi_period'].max()
# Out:
# 129995.7784

# %%
df['koi_period'].min()
# Out:
# 0.241842544
